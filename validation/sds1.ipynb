# %% [markdown]
# # Validation Notebook
#
# Testing all Sampling Design States in 4000 row validation file

# %%
from processbehavior import ProcessBehavior

# Load the SDS1 validation data
pb = ProcessBehavior.read_csv('TABVASTESTDATABASE.csv')

pb.cols
# Out:
# Found 11655 garbage/NA values across 5 column(s):
#   • PM SDS 2: 3200 values
#   • PM SDS 3: 958 values
#   • PM SDS 4: 2004 values
#   • PM SDS 5: 2134 values
#   • PM SDS 6: 3359 values
#
# These values were converted to NA and will be excluded from analysis.
# ColumnAccessor(['FACTOR 1', 'FACTOR 1xFACTOR 2', 'FACTOR 2', 'PM INERT', 'PM KNOWN', 'PM SDS 1', 'PM SDS 2', 'PM SDS 3', 'PM SDS 4', 'PM SDS 5', 'PM SDS 6', 'PRODUCTION TIME'])

# %%
pb.cols
# Out:
# ColumnAccessor(['FACTOR 1', 'FACTOR 1xFACTOR 2', 'FACTOR 2', 'PM INERT', 'PM KNOWN', 'PM SDS 1', 'PM SDS 2', 'PM SDS 3', 'PM SDS 4', 'PM SDS 5', 'PM SDS 6', 'PRODUCTION TIME'])

# %% [markdown]
# ## Formulation for PM1
# Tests sampling design state 1

# %%
study_pm1 = pb.formulate(
    response='PM SDS 1',
    time='PRODUCTION TIME',
    factors=['FACTOR 1', 'FACTOR 2'],
    precision=3
)
print(f'Sampling Design State: {study_pm1.sds}')
# Out:
# Sampling Design State: 1

# %% [markdown]
# # Create an Xbar Chart for PM1

# %%
# R5_Xbar
result = study_pm1.execute(chart='Xbar')
result.plot(chart='Xbar', template='ggplot').show()

# %% [markdown]
# # Create and S Chart for PM1

# %%
result.plot(chart='S',template='ggplot').show()

# %%
result.to_excel('PM_sds1_output.xlsx',include_full_dataset=True)

# %% [markdown]
# ## Formulation for PM2
# Tests sampling design state 2

# %%
study_pm2 = pb.formulate(
    response=pb.cols.PM_SDS_2,
    time='PRODUCTION TIME',
    factors=['FACTOR 1', 'FACTOR 2'],
    precision=2
)
print(f'Sampling Design State: {study_pm2.sds}')
# Out:
# Sampling Design State: 2

# %% [markdown]
# # Create Imr Chart for PM2

# %%
#result_pm_sds2 = study_pm_sds2.execute(chart='Imr', by=[pb.cols.FACTOR_1,pb.cols.FACTOR_2])

result_pm2_all = study_pm2.execute(chart='Imr', by=[])
#print(f'Strata: {result_pm_sds2_all.charts['Imr']['strata']}')
#print(f"Each stratum has its own IMR chart")
print("Imr data set")
result_pm2_all.chart_table(chart='Imr')
# Out:
# Imr data set
#     subgroup  n   value  center     lpl     upl signal
# 0        1_1  1  236.93  237.78  235.47  240.09
# 1        1_1  1  239.67  237.78  235.47  240.09
# 2        1_1  1  239.67  237.78  235.47  240.09
# 3        1_1  1  237.78  237.78  235.47  240.09
# 4        1_1  1  237.46  237.78  235.47  240.09
# ..       ... ..     ...     ...     ...     ...    ...
# 795      4_2  1  237.75  237.78  235.47  240.09
# 796      4_2  1  236.75  237.78  235.47  240.09
# 797      4_2  1  237.42  237.78  235.47  240.09
# 798      4_2  1  237.78  237.78  235.47  240.09
# 799      4_2  1  240.00  237.78  235.47  240.09
#
# [800 rows x 7 columns]

# %% [markdown]
# # Create R Chart for PM2

# %%
print("R data set")
result_pm2_all.chart_table(chart='R')
# Out:
# R data set
#     subgroup  n  value  center  lpl   upl signal
# 0        1_1  1   2.74    0.87  0.0  2.84
# 1        1_1  1   0.00    0.87  0.0  2.84
# 2        1_1  1   1.89    0.87  0.0  2.84
# 3        1_1  1   0.32    0.87  0.0  2.84
# 4        1_1  1   0.37    0.87  0.0  2.84
# ..       ... ..    ...     ...  ...   ...    ...
# 794      4_2  1   0.84    0.87  0.0  2.84
# 795      4_2  1   1.00    0.87  0.0  2.84
# 796      4_2  1   0.67    0.87  0.0  2.84
# 797      4_2  1   0.36    0.87  0.0  2.84
# 798      4_2  1   2.22    0.87  0.0  2.84
#
# [799 rows x 7 columns]

# %%
result_pm2_all.plot(chart='Imr', show_zones=True, template='ggplot').show()

# %%
result_pm2_all.plot(chart='R', show_zones=True,template='ggplot').show()

# %% [markdown]
# # Formulation for PM3

# %%
study_pm3 = pb.formulate(
    response=pb.cols.PM_SDS_3,
    time='PRODUCTION TIME',
    factors=['FACTOR 1', 'FACTOR 2'],
    precision=3
)
print(f'Sampling Design State: {study_pm3.sds}')
# Out:
# Sampling Design State: 3

# %%
# Xbar chart for factor 1
result_pm3 = study_pm3.execute(chart='Xbar')
result_pm3.plot(chart="Xbar").show()

# %%
#result_pm3.chart_table(chart="Xbar")

# Check if N is in statistics (will show "Varies" if n varies)                                                                                                                     
print(result_pm3.charts['Xbar']['statistics'])                                                                                                                                     
                                                                                                                                                                                     
# To get the actual n values, we need to look at the analysis dataset                                                                                                              
print(result_pm3._ads.analysis_dataset[['rsg', 'n']].drop_duplicates())                                                                                                            
                                                                                                                                                                                     
#Or check what S_bar is being used (this is what affects the limits):                                                                                                               
                                                                                                                                                                                     
# S_bar is stored as center in the S chart statistics                                                                                                                              
s_stats = result_pm3.charts['S']['statistics']                                                                                                                                     
print(f"S_bar (center): {s_stats['center']}")                                                                                                                                      
print(f"N: {s_stats['N']}")  # Will be "Varies" or a number                                                                                                                        
                                                                                                                                                                                     
# Get center from Xbar                                                                                                                                                             
xbar_stats = result_pm3.charts['Xbar']['statistics']                                                                                                                               
print(f"Xbar center: {xbar_stats['center']}")         

# Get S_bar (pooled standard deviation)                                                                                                                                            
s_stats = result_pm3.charts['S']['statistics']                                                                                                                                     
print(f"S_bar: {s_stats['center']}")                                                                                                                                  
                                                                                                                                                                                     
                                                                                                                                                                                     
center = 237.83                                                                                                                                                                    
S_bar = s_stats['center']                                                                                                                                                          
                                                                                                                                                                                     
print(f"\nLimits with different constant N:")                                                                                                                                      
for N in [2, 3, 4, 5]:                                                                                                                                                             
    lpl, upl = calculate_limits(mean=center, sd=S_bar, N=N, limits_type='Xbar', round_to=2)                                                                                        
    print(f"  N={N}: lpl={lpl}, upl={upl}")                                                                                                                                        
                                                                                                                                                                                     
print(f"\nTom expects: lpl=236.65, upl=239.01")        

# Get n values for subgroups that have n >= 2                                                                                                                                      
ads = result_pm3._ads.analysis_dataset                                                                                                                                             
n_per_kt = ads.groupby('rsg')['n'].first()  # n per kt cell                                                                                                                        
print(f"All n values: {sorted(n_per_kt.unique())}")                                                                                                                                
print(f"Mean n (all): {n_per_kt.mean():.2f}")                                                                                                                                      
print(f"Mean n (n>=2 only): {n_per_kt[n_per_kt >= 2].mean():.2f}")                                                                                                                 
                                                                                                                                                                                     
# Calculate with mean n                                                                                                                                                            
from processbehavior.spc_constants import calculate_limits                                                                                                                         
mean_n = n_per_kt.mean()                                                                                                                                                           
mean_n_filtered = n_per_kt[n_per_kt >= 2].mean()                                                                                                                                   
                                                                                                                                                                                     
S_bar = result_pm3.charts['S']['statistics']['center']                                                                                                                             
                                                                                                                                                                  
                                                                                                                                                                                     
print(f"\nWith mean n={mean_n:.2f}:")                                                                                                                                              
lpl, upl = calculate_limits(mean=center, sd=S_bar, N=mean_n, limits_type='Xbar', round_to=2)                                                                                       
print(f"  lpl={lpl}, upl={upl}")                                                                                                                                                   
                                                                                                                                                                                     
print(f"\nTom expects: lpl=236.65, upl=239.01")
# Out:
# {'center': np.float64(237.81), 'N': 'Varies', 'lpl': 'Varies', 'upl': 'Varies'}
#       rsg  n
# 0     1_1  5
# 5     1_1  4
# 9     1_1  2
# 21    1_1  3
# 376   1_2  3
# 379   1_2  2
# 384   1_2  5
# 392   1_2  4
# 481   1_2  1
# 756   2_1  4
# 760   2_1  3
# 767   2_1  5
# 973   2_1  2
# 1145  2_2  4
# 1149  2_2  3
# 1152  2_2  2
# 1154  2_2  5
# 1229  2_2  1
# 1525  3_1  4
# 1533  3_1  5
# 1551  3_1  3
# 1573  3_1  2
# 1731  3_1  1
# 1901  3_2  4
# 1905  3_2  3
# 1920  3_2  2
# 1934  3_2  5
# 2030  3_2  1
# 2288  4_1  5
# 2293  4_1  2
# 2300  4_1  4
# 2314  4_1  3
# 2339  4_1  1
# 2665  4_2  2
# 2667  4_2  4
# 2691  4_2  5
# 2711  4_2  1
# 2745  4_2  3
# S_bar (center): 0.798
# N: Varies
# Xbar center: 237.81
# S_bar: 0.798
#
# Limits with different constant N:
#   N=2: lpl=235.7083727404661, upl=239.95162725953392
#   N=3: lpl=236.2703807820059, upl=239.38961921799412
#   N=4: lpl=236.53077394744065, upl=239.12922605255937
#   N=5: lpl=236.69101516424809, upl=238.96898483575194
# ...

# %% [markdown]
# # Produce S Chart for PM3

# %%
result_pm3.plot(chart="S").show()

# %% [markdown]
# ## Formulation for PM4

# %%
study_pm4 = pb.formulate(
    response=pb.cols.PM_SDS_4,
    time='PRODUCTION TIME',
    factors=['FACTOR 1', 'FACTOR 2'],
    precision=3
)
print(f'Sampling Design State: {study_pm4.sds}')
pb.data.loc[pb.data["PRODUCTION TIME"] == 17].head()
# Out:
# Sampling Design State: 3
#     PRODUCTION TIME  FACTOR 1  FACTOR 2  FACTOR 1xFACTOR 2    PM SDS 1  \
# 80               17         1         1                 11  238.179993
# 81               17         1         1                 11  239.440367
# 82               17         1         1                 11  239.052919
# 83               17         1         1                 11  236.862445
# 84               17         1         1                 11  237.542326
#
#       PM SDS 2    PM SDS 3  PM SDS 4  PM SDS 5    PM SDS 6  PM INERT  \
# 80  238.179993  238.179993       NaN       NaN  238.179993 -1.387163
# 81         NaN  239.440367       NaN       NaN         NaN -0.650222
# 82         NaN         NaN       NaN       NaN         NaN -1.859792
# 83         NaN         NaN       NaN       NaN         NaN  1.774175
# 84         NaN  237.542326       NaN       NaN         NaN  1.068719
#
#       PM KNOWN
# 80  240.066002
# 81  237.678759
# 82  239.746021
# 83  238.415212
# ...

# %%
# Xbar chart for factor 2
result = study4.execute(chart='Xbar')
result.plot().show()

# %% [markdown]
# ## Recentered charts
#
# Using rc_ prefix or RCR numeric notation

# %%
# rc_noise_Xbar - recentered using alias prefix
result = study2.execute(chart='rc_noise_Xbar')
print('Charts in result:', list(result.charts.keys()))
result.plot(chart='R5_Xbar').show()
# Out:
# Charts in result: ['R5_Xbar']

# %%
# RCR5_Xbar - recentered using numeric notation
study_abc = pb.formulate(time=pb.cols.time,
                    factors = [pb.cols.time], 
                    response=pb.cols.y)
print(study_abc.support)
study_abc.execute('R5_S').plot('R5_S').show()
# Out:
#       chart  category  available  recommended                      reason  \
# 0      Xbar   primary       True         True                        None
# 1         S   primary       True        False                        None
# 2       Imr   primary       True        False                        None
# 3         R   primary       True        False                        None
# 4      R2_S  residual       True        False                        None
# 5    R2_Imr  residual      False        False  Not available for this SDS
# 6   R3_Xbar  residual       True        False                        None
# 7      R3_S  residual       True        False                        None
# 8    R3_Imr  residual      False        False  Not available for this SDS
# 9   R4_Xbar  residual       True        False                        None
# 10     R4_S  residual       True        False                        None
# 11   R4_Imr  residual      False        False  Not available for this SDS
# ...

# %%
result.plot(chart='S').show()
